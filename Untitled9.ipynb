# %% [markdown]
# <a href="https://colab.research.google.com/github/amanujlo/oop/blob/master/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install moodlepy --upgrade
# Out:
# ...
#      |████████████████████████████████| 147 kB 5.6 MB/s
# ...
#      |████████████████████████████████| 63 kB 818 kB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# ...

# %%
from moodle import Moodle
url = 'http://serwer2227349.home.pl/autoinstalator/moodle/webservice/rest/server.php'
token = 'a2edbd8bfa7d8c45a6b27e21422984e5'
moodle = Moodle(url, token)
dict_site_info = moodle('core_webservice_get_site_info')
site_info = moodle.core.webservice.get_site_info()  # return typed site_info

print(dict_site_info)
print(site_info)
# Out:
# {'sitename': 'serwer2227349.home.pl', 'username': 'pythonik', 'firstname': 'pythonik', 'lastname': 'pythonowski', 'fullname': 'pythonik pythonowski', 'lang': 'en', 'userid': 5, 'siteurl': 'http://serwer2227349.home.pl/autoinstalator/moodle', 'userpictureurl': 'http://serwer2227349.home.pl/autoinstalator/moodle/theme/image.php/boost/core/1651489581/u/f1', 'functions': [{'name': 'core_badges_get_user_badges', 'version': '2021051703'}, {'name': 'core_blog_get_entries', 'version': '2021051703'}, {'name': 'core_blog_view_entries', 'version': '2021051703'}, {'name': 'core_calendar_get_calendar_monthly_view', 'version': '2021051703'}, {'name': 'core_calendar_get_calendar_day_view', 'version': '2021051703'}, {'name': 'core_calendar_get_calendar_upcoming_view', 'version': '2021051703'}, {'name': 'core_calendar_update_event_start_day', 'version': '2021051703'}, {'name': 'core_calendar_create_calendar_events', 'version': '2021051703'}, {'name': 'core_calendar_delete_calendar_events', 'version':
# ...

# %%
from moodle import Moodle
url = 'http://serwer2227349.home.pl/autoinstalator/moodle/webservice/rest/server.php'
token = 'a2edbd8bfa7d8c45a6b27e21422984e5'
moodle = Moodle(url, token)
#dict_site_info = moodle('core_course_import_course')
site_info = moodle.core.course.get_courses()  # return typed site_info


#print(dict_site_info)
#print(site_info)

# %%
site_info
# Out:
# [Course(id=1, shortname='serwer2227349.home.pl', categoryid=0, fullname='serwer2227349.home.pl', displayname='serwer2227349.home.pl', summary='', summaryformat=1, format='site', showgrades=1, newsitems=3, startdate=0, enddate=0, maxbytes=0, showreports=0, visible=1, groupmode=0, groupmodeforce=0, defaultgroupingid=0, enablecompletion=0, completionnotify=0, lang='', categorysortorder=1, idnumber='', numsections=1, timecreated=1648205769, timemodified=1648205867, forcetheme='', hiddensections=None, courseformatoptions=[CourseFormatOption(name='numsections', value=1)], customfields=[]),
# ...
